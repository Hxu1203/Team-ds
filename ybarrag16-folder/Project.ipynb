# %%
import pandas as pd

from matplotlib import pyplot as plt

fifa_df = pd.read_csv('fifa_world_cup.csv')

# %%
#Used these atrributes: pd.set_option ('example')
#Lowered the numbers down to make it easier. 

pd.set_option('display.max_columns', None)

pd.set_option('display.max_rows', None)

fifa_world_cup.head(7)
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
# 5  1993-08-08      Peru      Colombia       South America       South America
# 6  1993-08-08  Zimbabwe      Eswatini              Africa              Africa
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# ...

# %%
#Is there really such a thing as a home team advantage?
#Do we find any evidence of home team advantage?

# %%
plt. bar(fifa_world_cup.home_team[0:7], fifa_world_cup.home_team_fifa_rank[0:7])

plt.xlabel('home_team')

plt.ylabel('home_team_fifa_rank')

plt.title("Countries vs.Fifa Ranks")

plt.show ()

# %%
plt. bar(fifa_world_cup.home_team_continent[0:7], fifa_world_cup.home_team_fifa_rank[0:7])

plt.xlabel('home_team')

plt.ylabel('home_team_fifa_rank')

plt.title("Countries vs.Fifa Ranks")

plt.show ()

# %%
plt. bar(fifa_world_cup.away_team[0:7], fifa_world_cup.away_team_fifa_rank[0:7])

plt.xlabel('away_team')

plt.ylabel('away_team_fifa_rank')

plt.title("Countries vs.Fifa Ranks")

plt.show ()

# %%
plt. bar(fifa_world_cup.away_team_continent[0:7], fifa_world_cup.away_team_fifa_rank[0:7])

plt.xlabel('away_team')

plt.ylabel('away_team_fifa_rank')

plt.title("Countries vs.Fifa Ranks")

plt.show ()

# %%
#Only from [0:6]: the home team does much better than the away team even though its not the whole data.

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23921 entries, 0 to 23920
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           23921 non-null  object
#  1   home_team                      23921 non-null  object
#  2   away_team                      23921 non-null  object
#  3   home_team_continent            23921 non-null  object
#  4   away_team_continent            23921 non-null  object
#  5   home_team_fifa_rank            23921 non-null  int64
#  6   away_team_fifa_rank            23921 non-null  int64
#  7   home_team_total_fifa_points    23921 non-null  int64
#  8   away_team_total_fifa_points    23921 non-null  int64
#  9   home_team_score                23921 non-null  int64
#  10  away_team_score                23921 non-null  int64
#  11  tournament                     23921 non-null  object
# ...

# %%
fifa_df['home_team_result'].value_counts(ascending=False).to_frame()
# Out:
#       home_team_result
# Win              11761
# Lose              6771
# Draw              5389

# %%
#Given 
variable1 = 11761
variable2 = 6771
variable3 = 5389
#--------------------------------
#Wins
variable = variable1 + variable2 + variable3
print(variable)
variable = 11761
variable = 23921
variable = variable1 / variable2
print(variable)
variable1 = 0.49166004765687055
variable2 = 100
variable = variable1 * variable2
print(variable)
#--------------------------------
#Loses 
variable1 = 6771
variable2 = 23921
variable = variable / variable2
print(variable)
variable = 0.28305672839764223
variable = 100
variable = variable1 * variable2
print(variable)
#--------------------------------
#Draws 
variable1 = 5389
variable2 = 23921
variable = variable1 / variable2
print(number)
variable1 = 0.22528322394548722
variable2 = 100
variable = variable1 * variable2
print(variable)
# Out:
# 23921
# 1.7369664746713926
# 49.166004765687056
# 0.0020553490558792298
# 161969091
# 166
# 22.528322394548724

# %%
#Approx. 
#home team: 49% wins, 28% loses, and 23% have draws in their games.

# %%
fifa_df.groupby('home_team_continent')['home_team_score'].value_counts(ascending=False).loc[lambda x :x<2].to_frame()
# Out:
#                                      home_team_score
# home_team_continent home_team_score
# Africa              12                             1
# Asia                13                             1
# Europe              11                             1
# North America       17                             1
# Oceania             10                             1
#                     12                             1
#                     16                             1
#                     17                             1
#                     22                             1
#                     31                             1
# South America       10                             1
#                     14                             1
#                     15                             1

# %%
#Given
variable1 = 12
variable2 = 13
variable3 = 11
variable4 = 17
variable5 = 108
variable6 = 39
#--------------------------------
variable = variable1 + variable2 + variable3 + variable4 + variable5 + variable6
print(variable)
# Out:
# 200

# %%
fifa_df.groupby('away_team_continent')['away_team_score'].value_counts(ascending=False).loc[lambda x :x<2].to_frame()
# Out:
#                                      away_team_score
# away_team_continent away_team_score
# Africa              9                              1
#                     10                             1
# Asia                15                             1
#                     17                             1
#                     21                             1
# Europe              10                             1
#                     11                             1
#                     13                             1
# North America       11                             1
# Oceania             11                             1
#                     14                             1
#                     15                             1
# South America       9                              1

# %%
#Given
variable1 = 19
variable2 = 53
variable3 = 34
variable4 = 11
variable5 = 40
variable6 = 9
#--------------------------------
variable = variable1 + variable2 + variable3 + variable4 + variable5 + variable6
print(variable)
# Out:
# 166

# %%
#The home team gets 200 score and away team gets 166 score; being in the home team does give an advantage.
